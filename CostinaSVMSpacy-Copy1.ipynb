# %%
import numpy as np
import csv
import pandas as pd
import pickle
import string
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
import re
import spacy

# %%
nlp = spacy.load('en_core_web_lg')

# %%
raw_data_neg = pd.read_csv('./twitter-datasets/train_neg.txt', header=None, sep="\n", encoding='utf-8', names=['text'],
                               error_bad_lines=False, warn_bad_lines=False, quoting=csv.QUOTE_NONE).drop_duplicates()
raw_data_neg['label'] = 0

raw_data_pos = pd.read_csv('./twitter-datasets/train_pos.txt', header=None, sep="\n", encoding='utf-8', names=['text'],
                               error_bad_lines=False, warn_bad_lines=False, quoting=csv.QUOTE_NONE).drop_duplicates()
raw_data_pos['label'] = 1

raw_data_train = pd.concat([raw_data_neg, raw_data_pos], ignore_index=True)


raw_data_test = pd.read_csv('./twitter-datasets/test_data.txt', header=None, sep="\n", encoding='utf-8', names=['text'],
                               error_bad_lines=False, warn_bad_lines=False, quoting=csv.QUOTE_NONE).drop_duplicates()


raw_data_test['id'], raw_data_test['text'] = raw_data_test['text'].apply(lambda x: x.split(',')[0]), raw_data_test['text'].apply(lambda x: ','.join(x.split(',')[1:]))

raw_data_train.head(20)
# Out:
#                                                 text  label
# 0  vinco tresorpack 6 ( difficulty 10 of 10 objec...      0
# 1  glad i dot have taks tomorrow ! ! #thankful #s...      0
# 2  1-3 vs celtics in the regular season = were fu...      0
# 3  <user> i could actually kill that girl i'm so ...      0
# 4  <user> <user> <user> i find that very hard to ...      0

# %% [markdown]
# # Preprocessing

# %%
# Use dictionary from http://luululu.com/tweet/typo-corpus-r1.txt
# http://people.eng.unimelb.edu.au/tbaldwin/etc/emnlp2012-lexnorm.tgz
# to handle abbreviations, mistakes...etc. (IN )

# LULU-CORPUS
# (1) INSERT (IN): a character is added to the original word.
# (2) REMOVE (RM): a character is removed from the original word.
# (3) REPLACE1 (R1): the order of character is different from the original word (the number of differences is one).
# (4) REPLACE2 (R2): a character is different from the original word

final_corpus = {}

def corpusReplace(corpus):
    for word in corpus:
        word = word.decode('utf8')
        word = word.split()
        final_corpus[word[0]] = word[1]    

corpus_lulu = open('corpus/lulu-corpus.txt', 'rb')
corpusReplace(corpus_lulu)
corpus_lulu.close()

corpus_emnlp = open('corpus/emnlp-corpus.txt', 'rb')
corpusReplace(corpus_emnlp)
corpus_emnlp.close()

def applyCorpus(tweet):
    new_tweet = ''
    for w in tweet.split(' '):
        if w in final_corpus.keys():
            #Replace with correct value
            new_word = final_corpus[w]
            new_tweet = new_tweet + ' ' + new_word
        else:
            new_tweet = new_tweet + ' ' + w
    return new_tweet

raw_data_train['text'] = raw_data_train.text.apply(applyCorpus)   
         
def cleanTweet(tweet):
    tweet = re.sub('<url>','',tweet)
    tweet = re.sub('<user>','',tweet)
    tweet = re.sub(r'\$\w*', '', tweet)
    tweet = tweet.lower()
    tweet = re.sub(r'https?:\/\/.*\/\w*', '', tweet)
    tweet = re.sub(r'#\w*', '', tweet) #hashtag
    tweet = re.sub(r'[' + punctuation.replace('@', '') + ']+', ' ', tweet) # puntuaction
    tweet = re.sub(r'\s\s+', ' ', tweet)
    tweet = tweet.lstrip(' ') 
    tweet = ''.join(c for c in tweet if c <= '\uFFFF') 
    return tweet

raw_data_train['text'] = raw_data_train.text.apply(cleanTweet)

# %%
raw_data_train.head(20)
# Out:
#                                                  text  label
# 0   vinco tresorpack 6 difficulty 10 of 10 object ...      0
# 1                     glad i dot have takes tomorrow       0
# 2   1 3 as celtics in the regular season were fuck...      0
# 3       i could actually kill that girl i m so sorry       0
# 4          i find that very hard to believe is afraid      0
# 5              wish i could be out all night tonight       0
# 6                            i got kicked out the wgm      0
# 7   it yes she is you tell it my lips are closed okay      0
# 8                              why is she so perfect       0
# 9   hi harry did you have good time in us i didnt ...      0
# 10  introduction to programming with see 2nd editi...      0
# 11                                         i m white       0
# 12              man i love and miss you don t be sad       0
# 13  so many wonderful building in do but still mis...      0
# 14  it s annoying because i secretly find it so good       0
# 15  the post boom in spanish america fiction suny ...      0
# 16  layers of the heart paperback this journey was...      0
# 17       guess who tested me again and wants us back       0
# 18  2 farrow v a litter offense wilful dispersal o...      0
# 19  99000 people at barca s ground tonight are gon...      0

# %% [markdown]
# # Feature extraction

# %%
def ngrams(tokens):
    # onegrams = tokens
    bigrams = [' '.join(t) for t in list(zip(tokens, tokens[1:]))]
    trigrams = [' '.join(t) for t in list(zip(tokens, tokens[1:], tokens[2:]))]
    return bigrams + trigrams

# example of use
# data = data.copy()
# data['grams'] = data.tokens.apply(ngrams)


# tokenize helper function
def tokenize(tweets):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in list(tweets) if char not in string.punctuation]
    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.lower().split() if word.lower() not in stopwords.words('english')]

raw_data_train = raw_data_train.copy()
raw_data_train['token'] = raw_data_train.text.apply(tokenize)

# %%
raw_data_train
# Out:
#                                                      text  label  \
# 0       vinco tresorpack 6 difficulty 10 of 10 object ...      0
# 1                         glad i dot have takes tomorrow       0
# 2       1 3 as celtics in the regular season were fuck...      0
# 3           i could actually kill that girl i m so sorry       0
# 4              i find that very hard to believe is afraid      0
# 5                  wish i could be out all night tonight       0
# 6                                i got kicked out the wgm      0
# 7       it yes she is you tell it my lips are closed okay      0
# 8                                  why is she so perfect       0
# 9       hi harry did you have good time in us i didnt ...      0
# 10      introduction to programming with see 2nd editi...      0
# 11                                             i m white       0
# 12                  man i love and miss you don t be sad       0
# 13      so many wonderful building in do but still mis...      0
# 14      it s annoying because i secretly find it so good       0
# 15      the post boom in spanish america fiction suny ...      0
# 16      layers of the heart paperback this journey was...      0
# 17           guess who tested me again and wants us back       0
# 18      2 farrow v a litter offense wilful dispersal o...      0
# 19      99000 people at barca s ground tonight are gon...      0
# 20            mlb 07 the show video game mlb 07 the show       0
# 21                             it if is not following you      0
# 22      why should i even care she don want my white a...      0
# 23      ugh id why i got my hopes up my plans never wo...      0
# 24      ummm playing trials had and ignoring the fact ...      0
# 25      trying to get tickets for the vancouver show t...      0
# 26      04x27 custom picture frame poster frame 1 5 wi...      0
# 27      soon i missed music class does this mean mi ag...      0
# 28      not when i m straight and i m taller than the ...      0
# 29      bloodforge not worth fighting to get decent co...      0
# ...                                                   ...    ...
# 181291   i like this song are like games i want you 2012       1
# 181292                     hey what s good take a listen       1
# 181293  don t apologize you are doing your best nobody...      1
# 181294        testing see h why and a she got me laughing      1
# 181295                   now i m following you white girl      1
# 181296  woohoo friday is here it s heating up between ...      1
# 181297  what did he do when you grab his ass or did he...      1
# 181298  oh yeah i know what ones those are good you ma...      1
# 181299  as long as you don make this awkward we should...      1
# 181300  i just ousted anna j as the mayor of anna s ho...      1
# 181301           kerp being all negative see what happens      1
# 181302  pro tip for fellas who like busty ladies rub h...      1
# 181303  jgn la takut you best dpt mumtaz punya when is...      1
# 181304  gonna be headed home from this job in a half h...      1
# 181305  shouts out to for telling me how it is even if...      1
# 181306  does it make you think of me dancing around li...      1
# 181307  i love knowing that i get to hang out with my ...      1
# 181308                        i ll enough fun for you too      1
# 181309  i just heard you re out with this tour sad i m...      1
# 181310                               aww thanks do him xd      1
# 181311  i may say i hate you like a billion times but ...      1
# 181312  can i be apart of the thumbs club please follo...      1
# 181313  linfield tickets go on sale tomorrow good deal...      1
# 181314                                coming to visit you      1
# 181315                                it really is a date      1
# 181316                                hey gina what s up       1
# 181317  has 9 1 3 and 9 2 east 5 s plus 8 statxact 8 h...      1
# 181318  u gord i just read your profile i m not sure i...      1
# 181319  i m so excited for tomorrow look out for two l...      1
# 181320  i always wondered what the job application is ...      1
#
#                                                     token
# 0       [vinco, tresorpack, 6, difficulty, 10, 10, obj...
# 1                            [glad, dot, takes, tomorrow]
# 2       [1, 3, celtics, regular, season, fucked, play,...
# 3                    [could, actually, kill, girl, sorry]
# 4                           [find, hard, believe, afraid]
# 5                           [wish, could, night, tonight]
# 6                                      [got, kicked, wgm]
# 7                         [yes, tell, lips, closed, okay]
# 8                                               [perfect]
# 9       [hi, harry, good, time, us, didnt, get, 2, see...
# 10      [introduction, programming, see, 2nd, edition,...
# 11                                                [white]
# 12                                 [man, love, miss, sad]
# 13               [many, wonderful, building, still, miss]
# 14                       [annoying, secretly, find, good]
# 15      [post, boom, spanish, america, fiction, suny, ...
# 16      [layers, heart, paperback, journey, inspired, ...
# 17                       [guess, tested, wants, us, back]
# 18      [2, farrow, v, litter, offense, wilful, disper...
# 19      [99000, people, barca, ground, tonight, gonna,...
# 20            [mlb, 07, show, video, game, mlb, 07, show]
# 21                                            [following]
# 22                [even, care, want, white, ass, anyways]
# 23              [ugh, id, got, hopes, plans, never, work]
# 24       [ummm, playing, trials, ignoring, fact, need, 7]
# 25      [trying, get, tickets, vancouver, show, row, 1...
# 26      [04x27, custom, picture, frame, poster, frame,...
# 27      [soon, missed, music, class, mean, mi, ago, fa...
# 28                         [straight, taller, cute, boys]
# 29      [bloodforge, worth, fighting, get, decent, com...
# ...                                                   ...
# 181291              [like, song, like, games, want, 2012]
# 181292                          [hey, good, take, listen]
# 181293                  [apologize, best, nobody, better]
# 181294                   [testing, see, h, got, laughing]
# 181295                           [following, white, girl]
# 181296  [woohoo, friday, heating, two, entries, well, ...
# 181297                                  [grab, ass, care]
# 181298  [oh, yeah, know, ones, good, made, wow, kudos, 3]
# 181299            [long, make, awkward, good, real, good]
# 181300              [ousted, anna, j, mayor, anna, house]
# 181301                     [kerp, negative, see, happens]
# 181302  [pro, tip, fellas, like, busty, ladies, rub, s...
# 181303   [jgn, la, takut, best, dpt, mumtaz, punya, exam]
# 181304             [gonna, headed, home, job, half, hour]
# 181305         [shouts, telling, even, like, least, told]
# 181306  [make, think, dancing, around, like, loon, pai...
# 181307  [love, knowing, get, hang, friends, instead, p...
# 181308                                      [enough, fun]
# 181309  [heard, tour, sad, overseas, see, cause, troub...
# 181310                                  [aww, thanks, xd]
# 181311  [may, say, hate, like, billion, times, care, k...
# 181312  [apart, thumbs, club, please, follow, pretty, ...
# 181313  [linfield, tickets, go, sale, tomorrow, good, ...
# 181314                                    [coming, visit]
# 181315                                     [really, date]
# 181316                                        [hey, gina]
# 181317  [9, 1, 3, 9, 2, east, 5, plus, 8, statxact, 8,...
# 181318  [u, gord, read, profile, sure, lunch, riders, ...
# 181319    [excited, tomorrow, look, two, leprechauns, xd]
# 181320  [always, wondered, job, application, like, hoo...
#
# [181321 rows x 3 columns]

# %%
# https://github.com/Wronskia/Sentiment-Analysis-on-Twitter-data/blob/master/Final/features.py
# def ngramFeatureAugmentation(tweets_tfidf):
#     new_tweets = []
#     for t in tweets:
        


# def add_ngram(sequences, token_indice, ngram_range=2):
#     """
#     Augment the input list of list (sequences) by appending n-grams values.
#     Example: adding bi-gram
#     >>> sequences = [[1, 3, 4, 5], [1, 3, 7, 9, 2]]
#     >>> token_indice = {(1, 3): 1337, (9, 2): 42, (4, 5): 2017}
#     >>> add_ngram(sequences, token_indice, ngram_range=2)
#     [[1, 3, 4, 5, 1337, 2017], [1, 3, 7, 9, 2, 1337, 42]]
#     Example: adding tri-gram
#     >>> sequences = [[1, 3, 4, 5], [1, 3, 7, 9, 2]]
#     >>> token_indice = {(1, 3): 1337, (9, 2): 42, (4, 5): 2017, (7, 9, 2): 2018}
#     >>> add_ngram(sequences, token_indice, ngram_range=3)
#     [[1, 3, 4, 5, 1337], [1, 3, 7, 9, 2, 1337, 2018]]
#     """
#     new_sequences = []
#     for input_list in sequences:
#         new_list = input_list[:]
#         for i in range(len(new_list)-ngram_range+1):
#             for ngram_value in range(2, ngram_range+1):
#                 ngram = tuple(new_list[i:i+ngram_value])
#                 if ngram in token_indice:
#                     new_list.append(token_indice[ngram])
#         new_sequences.append(new_list)

#     return new_sequences

# %% [markdown]
# # Train
